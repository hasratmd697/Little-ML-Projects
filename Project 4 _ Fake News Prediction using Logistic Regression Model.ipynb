# %%
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "train (2).csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "aadyasingh55/fake-news-classification",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

# print("First 5 records:", df.head())
news_dataset = pd.Dataframe(df)
# Out:
# /tmp/ipython-input-7-3298716055.py:10: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
# ...
# 100%|██████████| 60.4M/60.4M [00:02<00:00, 27.3MB/s]
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/kagglehub/pandas_datasets.py in load_pandas_dataset(handle, path, pandas_kwargs, sql_query)
#      90     try:
# ---> 91         result = read_function(
#      92             *_build_args(read_function, filepath, sql_query),
#
# ...

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "train (2).csv"

# Load the latest version
# Add the 'engine="python"' argument to handle potential parsing issues
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "aadyasingh55/fake-news-classification",
  file_path,
  pandas_kwargs={'engine': 'python'} # Pass pandas arguments via pandas_kwargs
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

# print("First 5 records:", df.head())
# news_dataset = pd.Dataframe(df) # This line has a typo, DataFrame should be capitalized

# Correct the typo in DataFrame
news_dataset = pd.DataFrame(df)
# Out:
# /tmp/ipython-input-8-2077081670.py:11: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/python_parser.py in _next_iter_line(self, row_num)
#     804             assert self.data is not None
# --> 805             line = next(self.data)
#     806             # for mypy
#
# Error: ',' expected after '"'
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/kagglehub/pandas_datasets.py in load_pandas_dataset(handle, path, pandas_kwargs, sql_query)
#      90     try:
# ---> 91         result = read_function(
# ...

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "train (2).csv"

# Load the latest version
# Add the 'engine="python"' argument to handle potential parsing issues
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "aadyasingh55/fake-news-classification",
  file_path,
  pandas_kwargs={'engine': 'python', 'on_bad_lines': 'skip'} # Pass pandas arguments via pandas_kwargs, including skipping bad lines
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

# print("First 5 records:", df.head())
# news_dataset = pd.Dataframe(df) # This line has a typo, DataFrame should be capitalized

# Correct the typo in DataFrame
news_dataset = pd.DataFrame(df)
# Out:
# /tmp/ipython-input-9-2190630487.py:11: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(

# %%
news_dataset.shape
# Out:
# (19286, 1)
